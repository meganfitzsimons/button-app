# %%
from io import BytesIO
import json

import cartopy.crs as ccrs
import iris
import iris.plot as iplt
import requests

# %%
cubes = iris.load('/s3/turnkey-supercell-york/ukv_20180718_03.pp')
print(cubes)
# Out:
# 0: air_pressure_at_sea_level / (Pa)    (time: 16; grid_latitude: 810; grid_longitude: 621)
# 1: air_temperature / (K)               (time: 16; grid_latitude: 810; grid_longitude: 621)
# 2: air_temperature / (K)               (time: 15; grid_latitude: 810; grid_longitude: 621)
# 3: air_temperature / (K)               (time: 15; grid_latitude: 810; grid_longitude: 621)
# 4: dew_point_temperature / (K)         (time: 16; grid_latitude: 810; grid_longitude: 621)
# 5: relative_humidity / (%)             (time: 16; grid_latitude: 810; grid_longitude: 621)
# 6: x_wind / (m s-1)                    (time: 16; grid_latitude: 811; grid_longitude: 621)
# 7: y_wind / (m s-1)                    (time: 16; grid_latitude: 811; grid_longitude: 621)

# %%
cube = cubes[4]
cube
# Out:
# <iris 'Cube' of dew_point_temperature / (K) (time: 16; grid_latitude: 810; grid_longitude: 621)>

# %%
iplt.pcolormesh(cube[0])
iplt.plt.gca().coastlines()
# Out:
# /opt/conda/lib/python3.6/site-packages/iris/coords.py:1138: UserWarning: Coordinate 'grid_longitude' is not bounded, guessing contiguous bounds.
#   'contiguous bounds.'.format(self.name()))
# /opt/conda/lib/python3.6/site-packages/iris/coords.py:1138: UserWarning: Coordinate 'grid_latitude' is not bounded, guessing contiguous bounds.
#   'contiguous bounds.'.format(self.name()))

# %%
# %%capture --no-stderr --no-stdout my_img
_ = iplt.pcolormesh(cube[0])
_ = iplt.plt.gca().coastlines()
# Out:
# /opt/conda/lib/python3.6/site-packages/iris/coords.py:1138: UserWarning: Coordinate 'grid_longitude' is not bounded, guessing contiguous bounds.
#   'contiguous bounds.'.format(self.name()))
# /opt/conda/lib/python3.6/site-packages/iris/coords.py:1138: UserWarning: Coordinate 'grid_latitude' is not bounded, guessing contiguous bounds.
#   'contiguous bounds.'.format(self.name()))

# %%
my_img.show()

# %%
/ourl = 'https://ikaf6tvl9d.execute-api.eu-west-1.amazonaws.com/dev/upload-png'
headers = {'mimetype': 'image/png',
           'filename': 'my_img.png',
           'Content-Type': 'application/octet-stream'}
payload = my_img.outputs[0].data['image/png']

requests.post(url, data=payload, headers=headers)

# url = 'https://ikaf6tvl9d.execute-api.eu-west-1.amazonaws.com/dev/upload-png'
# bn = BytesIO(my_img.outputs[0].data['image/png'])
# Out:
# <Response [200]>

# %%
print('kjh')
# Out:
# kjh
